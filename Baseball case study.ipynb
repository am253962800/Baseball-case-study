# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.shape
# Out:
# (30, 17)

# %%
df.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ER    30.0   635.833333   70.140786   478.00   587.2500   644.500   679.25
# ERA   30.0     3.956333    0.454089     2.94     3.6825     4.025     4.22
# CG    30.0     3.466667    2.763473     0.00     1.0000     3.000     5.75
# SHO   30.0    11.300000    4.120177     4.00     9.0000    12.000    13.00
# SV    30.0    43.066667    7.869335    28.00    37.2500    42.000    46.75
# E     30.0    94.333333   13.958889    75.00    86.0000    91.000    96.75
#
#          max
# W     100.00
# R     891.00
# AB   5649.00
# H    1515.00
# 2B    308.00
# 3B     49.00
# HR    232.00
# BB    570.00
# SO   1518.00
# SB    134.00
# RA    844.00
# ER    799.00
# ERA     5.04
# CG     11.00
# SHO    21.00
# SV     62.00
# E     126.00

# %%
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
sns.displot(df.W)

# %%
sns.histplot(df.W,bins=30)
# Out:
# <Axes: xlabel='W', ylabel='Count'>

# %% [markdown]
# # NULL CHECK

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # CORRELATION()

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df=df[['R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E','W']]

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linecolor='white',linewidths=.25)
# Out:
# <Axes: >

# %% [markdown]
# R,HR,2B,BB,SHO, SV  is good correlated with target variable (W)
# AB, H, 3B, SO,SB,CG,E  are low correlated with target variable (+ and -)
# RA, ER, ERA  are highly negative correlated, we have to further check to drop any of them.
# RA, ER, ERA  are highly correlated to each other. these feature can bios the result. we have to take decicion on them.
# AB and H are strong correlated to each other 74%

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E', 'W'],
#       dtype='object')

# %%
sns.scatterplot(data=df,x='R',y='W')
# Out:
# <Axes: xlabel='R', ylabel='W'>

# %%
sns.scatterplot(data=df,x='AB',y='W')
# Out:
# <Axes: xlabel='AB', ylabel='W'>

# %% [markdown]
# low correlated

# %%
sns.scatterplot(data=df,x='H',y='W')
# Out:
# <Axes: xlabel='H', ylabel='W'>

# %% [markdown]
# low correlated

# %%
sns.scatterplot(data=df,x='2B',y='W')
# Out:
# <Axes: xlabel='2B', ylabel='W'>

# %% [markdown]
# positive correlated

# %%
sns.scatterplot(data=df,x='3B',y='W')
# Out:
# <Axes: xlabel='3B', ylabel='W'>

# %% [markdown]
# low correlated

# %%
sns.scatterplot(data=df,x='HR',y='W')
# Out:
# <Axes: xlabel='HR', ylabel='W'>

# %% [markdown]
# positive correlated

# %%
sns.scatterplot(data=df,x='BB',y='W')
# Out:
# <Axes: xlabel='BB', ylabel='W'>

# %% [markdown]
# positive corelated

# %%
sns.scatterplot(data=df,x='SO',y='W')
# Out:
# <Axes: xlabel='SO', ylabel='W'>

# %% [markdown]
# low positive correlated

# %%
sns.scatterplot(data=df,x='RA',y='W')
# Out:
# <Axes: xlabel='RA', ylabel='W'>

# %% [markdown]
# Highly negative correlated

# %%
sns.scatterplot(data=df,x='ER',y='W')
# Out:
# <Axes: xlabel='ER', ylabel='W'>

# %% [markdown]
# highly negative correlated

# %%
sns.scatterplot(data=df,x='ERA',y='W')
# Out:
# <Axes: xlabel='ERA', ylabel='W'>

# %% [markdown]
# highly negative correalted

# %%
sns.scatterplot(data=df,x='CG',y='W')
# Out:
# <Axes: xlabel='CG', ylabel='W'>

# %% [markdown]
# very low correlated

# %%
sns.scatterplot(data=df,x='SHO',y='W')
# Out:
# <Axes: xlabel='SHO', ylabel='W'>

# %% [markdown]
# Positive correlated

# %%
sns.scatterplot(data=df,x='SV',y='W')
# Out:
# <Axes: xlabel='SV', ylabel='W'>

# %% [markdown]
# Positive correlated

# %%
sns.scatterplot(data=df,x='E',y='W')
# Out:
# <Axes: xlabel='E', ylabel='W'>

# %% [markdown]
# very low correlated

# %% [markdown]
# conclusion: some variables are very low correlated and some are highly negative correlated and also multicollinearity is found & some highly independent to each other

# %% [markdown]
# # UNIQUES VALUES

# %%
for i in df.columns:
    df[i].nunique()
    print("unique value of feature",i,'=',df[i].nunique())
# Out:
# unique value of feature R = 28
# unique value of feature AB = 29
# unique value of feature H = 29
# unique value of feature 2B = 22
# unique value of feature 3B = 23
# unique value of feature HR = 27
# unique value of feature BB = 29
# unique value of feature SO = 29
# unique value of feature SB = 27
# unique value of feature RA = 30
# unique value of feature ER = 30
# unique value of feature ERA = 30
# unique value of feature CG = 9
# unique value of feature SHO = 12
# unique value of feature SV = 20
# unique value of feature E = 21
# unique value of feature W = 24

# %%
df.CG.unique()
# Out:
# array([ 2, 11,  7,  3,  0,  1,  5,  6,  4], dtype=int64)

# %%
sns.scatterplot(data=df, x="R", y="W",size='CG')
# Out:
# <Axes: xlabel='R', ylabel='W'>

# %%
sns.scatterplot(data=df,x='CG',y='W')
# Out:
# <Axes: xlabel='CG', ylabel='W'>

# %% [markdown]
# Complete game has no correlation with WIN.There are chances where you played complete game and not won all matches

# %% [markdown]
# # VIF to find MULTICOLLINEARITY

# %%
v=df.drop('W',axis=1)
v.head(2)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
#
#     E
# 0  88
# 1  86

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF=pd.DataFrame()
VIF['features']=v.columns

# %%
VIF['vif']=[variance_inflation_factor(scaled,i)for i in range(len(v.columns))]

# %%
VIF
# Out:
#    features          vif
# 0         R    11.522370
# 1        AB    13.311532
# 2         H    10.070668
# 3        2B     4.019297
# 4        3B     3.294146
# 5        HR    10.079902
# 6        BB     3.806098
# 7        SO     2.652401
# 8        SB     2.102684
# 9        RA   191.839155
# 10       ER  1680.387145
# 11      ERA  1222.722240
# 12       CG     3.059904
# 13      SHO     3.654331
# 14       SV     5.798850
# 15        E     2.186219

# %% [markdown]
# Delete feature 'ER'

# %%
v=df.drop(['W','ER'],axis=1)

# %%
v.head(2)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ERA  CG  SHO  SV   E
# 0  724  5575  1497  300  42  139  383   973  104  641  3.73   2    8  56  88
# 1  696  5467  1349  277  44  156  439  1264   70  700  4.07   2   12  45  86

# %%
scaled=sc.fit_transform(v)

# %%
VIF2=pd.DataFrame()
VIF2['features']=v.columns
VIF2['vif']=[variance_inflation_factor(scaled,i)for i in range(len(v.columns))]

# %%
VIF2
# Out:
#    features         vif
# 0         R   11.158733
# 1        AB    5.863764
# 2         H    9.628749
# 3        2B    3.786446
# 4        3B    3.293109
# 5        HR    9.057309
# 6        BB    3.791451
# 7        SO    2.607389
# 8        SB    1.849280
# 9        RA  122.133235
# 10      ERA  119.328698
# 11       CG    2.741188
# 12      SHO    3.410561
# 13       SV    3.203815
# 14        E    2.107345

# %% [markdown]
# Delete RA column

# %%
v=df.drop(['W','ER','RA'],axis=1)

# %%
scaled=sc.fit_transform(v)

# %%
VIF3=pd.DataFrame()
VIF3['features']=v.columns
VIF3['vif']=[variance_inflation_factor(scaled,i)for i in range(len(v.columns))]

# %%
VIF3
# Out:
#    features        vif
# 0         R  10.987898
# 1        AB   4.399954
# 2         H   8.941874
# 3        2B   3.729413
# 4        3B   3.142717
# 5        HR   7.882841
# 6        BB   3.468244
# 7        SO   2.155496
# 8        SB   1.819823
# 9       ERA   4.951981
# 10       CG   2.723370
# 11      SHO   3.227759
# 12       SV   2.948133
# 13        E   2.040676

# %%
v.head(3)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV   E
# 0  724  5575  1497  300  42  139  383   973  104  3.73   2    8  56  88
# 1  696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45  86
# 2  669  5439  1395  303  29  141  533  1157   86  3.67  11   10  38  79

# %%
plt.figure(figsize=(12,10))
sns.heatmap(v.corr(),annot=True,linecolor='black',linewidths=.25)
# Out:
# <Axes: >

# %% [markdown]
# all highly correlated features have been removed

# %%
v.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # OUTLIERS

# %%
for i in v.columns:
    sns.boxplot(v[i])
    plt.show()

# %%
v.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO',
#        'SV', 'E'],
#       dtype='object')

# %% [markdown]
# outliers in upper range of feature R,ERA,SHO,SV,E.

# %% [markdown]
# # SEPARATE DEPENDENT & INDEPENDENT FEATURES

# %%
x=scaled

# %%
y=df['W']

# %%
x.shape
# Out:
# (30, 14)

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# # ML MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
LR=LinearRegression()

# %%
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.2)
    LR.fit(x_train,y_train)
    train_pred=LR.predict(x_train)
    test_pred=LR.predict(x_test)
    if round (r2_score(y_test,test_pred),2)==round(r2_score(y_train,train_pred),2):
        print("At random state",i,"The model performance very well")
        print("At random state:",i)
        print("Test R2 score is:",round(r2_score(y_test,test_pred),2))
        print("Train R2 score is:",round(r2_score(y_train,train_pred),2))
        print('x'*50,'\n')
# Out:
# At random state 6 The model performance very well
# At random state: 6
# Test R2 score is: 0.93
# Train R2 score is: 0.93
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# At random state 165 The model performance very well
# At random state: 165
# Test R2 score is: 0.93
# Train R2 score is: 0.93
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=165,test_size=.2)
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import sys

# !{sys.executable} -m pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/24/ec/ad387100fa3cc2b9b81af0829b5ecfe75ec5bb19dd7c19d4fea06fb81802/xgboost-2.0.3-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.11.1)
# Downloading xgboost-2.0.3-py3-none-win_amd64.whl (99.8 MB)
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 119.1 kB/s eta 0:13:58
#    ---------------------------------------- 0.0/99.8 MB 119.1 kB/s eta 0:13:58
#    ---------------------------------------- 0.0/99.8 MB 109.3 kB/s eta 0:15:13
#    ---------------------------------------- 0.0/99.8 MB 109.3 kB/s eta 0:15:13
#    ---------------------------------------- 0.0/99.8 MB 109.3 kB/s eta 0:15:13
#    ---------------------------------------- 0.1/99.8 MB 121.3 kB/s eta 0:13:42
#    ---------------------------------------- 0.1/99.8 MB 148.1 kB/s eta 0:11:13
#    ---------------------------------------- 0.1/99.8 MB 148.1 kB/s eta 0:11:13
#    ---------------------------------------- 0.1/99.8 MB 148.1 kB/s eta 0:11:13
#    ---------------------------------------- 0.1/99.8 MB 148.1 kB/s eta 0:11:13
#    ---------------------------------------- 0.1/99.8 MB 148.1 kB/s eta 0:11:13
#    ---------------------------------------- 0.1/99.8 MB 148.1 kB/s eta 0:11:13
#    ---------------------------------------- 0.1/99.8 MB 148.1 kB/s eta 0:11:13
#    ---------------------------------------- 0.1/99.8 MB 148.1 kB/s eta 0:11:13
#    ---------------------------------------- 0.2/99.8 MB 218.6 kB/s eta 0:07:36
#    ---------------------------------------- 0.2/99.8 MB 218.6 kB/s eta 0:07:36
#    ---------------------------------------- 0.2/99.8 MB 218.6 kB/s eta 0:07:36
#    ---------------------------------------- 0.2/99.8 MB 214.9 kB/s eta 0:07:44
#    ---------------------------------------- 0.2/99.8 MB 221.9 kB/s eta 0:07:29
#    ---------------------------------------- 0.2/99.8 MB 221.9 kB/s eta 0:07:29
#    ---------------------------------------- 0.2/99.8 MB 209.4 kB/s eta 0:07:56
#    ---------------------------------------- 0.3/99.8 MB 221.5 kB/s eta 0:07:30
#    ---------------------------------------- 0.3/99.8 MB 218.6 kB/s eta 0:07:36
#    ---------------------------------------- 0.3/99.8 MB 218.6 kB/s eta 0:07:36
#    ---------------------------------------- 0.3/99.8 MB 236.9 kB/s eta 0:07:00
#    ---------------------------------------- 0.3/99.8 MB 239.0 kB/s eta 0:06:56
#    ---------------------------------------- 0.3
kB/s eta 0:00:02
#    ---------------------------------------  99.3/99.8 MB 438.2 kB/s eta 0:00:02
#    ---------------------------------------  99.3/99.8 MB 437.6 kB/s eta 0:00:02
#    ---------------------------------------  99.3/99.8 MB 437.1 kB/s eta 0:00:01
#    ---------------------------------------  99.4/99.8 MB 436.5 kB/s eta 0:00:01
#    ---------------------------------------  99.4/99.8 MB 435.6 kB/s eta 0:00:01
#    ---------------------------------------  99.4/99.8 MB 435.0 kB/s eta 0:00:01
#    ---------------------------------------  99.5/99.8 MB 435.3 kB/s eta 0:00:01
#    ---------------------------------------  99.5/99.8 MB 435.3 kB/s eta 0:00:01
#    ---------------------------------------  99.5/99.8 MB 434.4 kB/s eta 0:00:01
#    ---------------------------------------  99.5/99.8 MB 433.6 kB/s eta 0:00:01
#    ---------------------------------------  99.6/99.8 MB 433.9 kB/s eta 0:00:01
#    ---------------------------------------  99.6/99.8 MB 434.1 kB/s eta 0:00:01
#    ---------------------------------------  99.6/99.8 MB 434.2 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 433.0 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 431.6 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 431.6 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 431.6 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 431.6 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 431.6 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 431.6 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 431.6 kB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 431.6 kB/s eta 0:00:01
#    ---------------------------------------- 99.8/99.8 MB 420.4 kB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor 
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
LR_model=LinearRegression()
RD_model=Ridge()
LS_model=Lasso()
DT_model=DecisionTreeRegressor()
SV_model=SVR()
KNR_model=KNeighborsRegressor()
RFR_model=RandomForestRegressor()
XBG_model= XGBRegressor()
Elastic_model=ElasticNet()
SGH_model=SGDRegressor()
Bag_model=BaggingRegressor()
ADA_model=AdaBoostRegressor()
GB_model=GradientBoostingRegressor
model=[LR_model,RD_model,LS_model,DT_model,SV_model,KNR_model,RFR_model,XBG_model,Elastic_model,SGH_model,Bag_model,ADA_model,GB_model]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
for m in model:
    m.fit(x_train,y_train)
    print('mean_absolute_error of',m,'model',mean_absolute_error(y_test,m.predict(x_test)))
    print('mean_squared_error of ',m,'model',mean_squared_error(y_test,m.predict(x_test)))
    print('R2 Score of',m , 'model',r2_score(y_test,m.predict(x_test))*100)
    print('x'*50,'\n\n')
# Out:
# mean_absolute_error of LinearRegression() model 2.3190366161382037
# mean_squared_error of  LinearRegression() model 10.516590710591345
# R2 Score of LinearRegression() model 92.85260967375328
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of Ridge() model 3.285263140848732
# mean_squared_error of  Ridge() model 13.056756086054856
# R2 Score of Ridge() model 91.1262371323773
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of Lasso() model 4.83177051570689
# mean_squared_error of  Lasso() model 27.49299137242303
# R2 Score of Lasso() model 81.31493884449257
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of DecisionTreeRegressor() model 8.0
# mean_squared_error of  DecisionTreeRegressor() model 80.0
# R2 Score of DecisionTreeRegressor() model 45.62960166131773
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of SVR() model 12.569891104336435
# mean_squared_error of  SVR() model 191.72693768210704
# R2 Score of SVR() model -30.303374675398388
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of KNeighborsRegressor() model 8.033333333333331
# mean_squared_error of  KNeighborsRegressor() model 84.24666666666666
# R2 Score of KNeighborsRegressor() model 42.743439682839345
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of RandomForestRegressor() model 7.755
# mean_squared_error of  RandomForestRegressor() model 76.83448333333335
# R2 Score of RandomForestRegressor() model 47.78098168774777
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) model 7.396114349365234
# mean_squared_error of  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) model 61.35171934235647
# R2 Score of XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) model 58.303532257413
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of ElasticNet() model 6.983412322272424
# mean_squared_error of  ElasticNet() model 56.08069719550702
# R2 Score of ElasticNet() model 61.88587692961577
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of SGDRegressor() model 4.521587936564121
# mean_squared_error of  SGDRegressor() model 25.03951823366207
# R2 Score of SGDRegressor() model 82.9823927428387
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of BaggingRegressor() model 7.416666666666667
# mean_squared_error of  BaggingRegressor() model 72.50166666666667
# R2 Score of BaggingRegressor() model 50.72569378893714
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# mean_absolute_error of AdaBoostRegressor() model 6.76984126984127
# mean_squared_error of  AdaBoostRegressor() model 64.95275888133033
# R2 Score of AdaBoostRegressor() model 55.856157830321095
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[104], line 3
#       1 from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
#       2 for m in model:
# ----> 3     m.fit(x_train,y_train)
#       4     print('mean_absolute_error of',m,'model',mean_absolute_error(y_test,m.predict(x_test)))
#       5     print('mean_squared_error of ',m,'model',mean_squared_error(y_test,m.predict(x_test)))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1144, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1139 partial_fit_and_fitted = (
#    1140     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141 )
#    1143 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
#    1151     return fit_method(estimator, *args, **kwargs)
#
# AttributeError: 'numpy.ndarray' object has no attribute '_validate_params'

# %% [markdown]
# # CROSS-VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in model:
    print('mean_square of',i,'model', mean_squared_error(y_test,i.predict(x_test)))
    print('cross Validation score of ',i,"is",cross_val_score(i,x,y,scoring='neg_mean_squared_error').mean())
    print('*'*50)
# Out:
# mean_square of LinearRegression() model 10.516590710591345
# cross Validation score of  LinearRegression() is -31.79209642779955
# **************************************************
# mean_square of Ridge() model 13.056756086054856
# cross Validation score of  Ridge() is -27.30678513765411
# **************************************************
# mean_square of Lasso() model 27.49299137242303
# cross Validation score of  Lasso() is -21.91636991314075
# **************************************************
# mean_square of DecisionTreeRegressor() model 80.0
# cross Validation score of  DecisionTreeRegressor() is -137.93333333333334
# **************************************************
# mean_square of SVR() model 191.72693768210704
# cross Validation score of  SVR() is -105.99710538373984
# **************************************************
# mean_square of KNeighborsRegressor() model 84.24666666666666
# cross Validation score of  KNeighborsRegressor() is -64.78266666666669
# **************************************************
# mean_square of RandomForestRegressor() model 76.83448333333335
# cross Validation score of  RandomForestRegressor() is -68.44770333333334
# **************************************************
# mean_square of XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) model 61.35171934235647
# cross Validation score of  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) is -88.39678135463814
# **************************************************
# mean_square of ElasticNet() model 56.08069719550702
# cross Validation score of  ElasticNet() is -39.0533573594194
# **************************************************
# mean_square of SGDRegressor() model 25.03951823366207
# cross Validation score of  SGDRegressor() is -28.927610525924734
# **************************************************
# mean_square of BaggingRegressor() model 72.50166666666667
# cross Validation score of  BaggingRegressor() is -76.22866666666667
# **************************************************
# mean_square of AdaBoostRegressor() model 64.95275888133033
# cross Validation score of  AdaBoostRegressor() is -70.85508092403629
# **************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 2
#       1 for i in model:
# ----> 2     print('mean_square of',i,'model', mean_squared_error(y_test,i.predict(x_test)))
#       3     print('cross Validation score of ',i,"is",cross_val_score(i,x,y,scoring='neg_mean_squared_error').mean())
#       4     print('*'*50)
#
# TypeError: GradientBoostingRegressor.predict() missing 1 required positional argument: 'X'

# %%
for i in model:
    print('Root mean_square of ',i, 'model',np.sqrt(mean_squared_error(y_test,i.predict(x_test))))
    score=cross_val_score(i,x,y,cv=10, scoring='neg_mean_squared_error').mean()
    print("cross Validation score of root mean square ",i ," is ",np.sqrt(-score))
    print('*'*50)
# Out:
# Root mean_square of  LinearRegression() model 3.242929340980365
# cross Validation score of root mean square  LinearRegression()  is  5.743949955797924
# **************************************************
# Root mean_square of  Ridge() model 3.6134133566552906
# cross Validation score of root mean square  Ridge()  is  5.54406091397667
# **************************************************
# Root mean_square of  Lasso() model 5.2433759518484875
# cross Validation score of root mean square  Lasso()  is  4.529900320875452
# **************************************************
# Root mean_square of  DecisionTreeRegressor() model 8.94427190999916
# cross Validation score of root mean square  DecisionTreeRegressor()  is  10.56251232740898
# **************************************************
# Root mean_square of  SVR() model 13.846549667050887
# cross Validation score of root mean square  SVR()  is  10.049052194874193
# **************************************************
# Root mean_square of  KNeighborsRegressor() model 9.178598295309946
# cross Validation score of root mean square  KNeighborsRegressor()  is  7.690080190305777
# **************************************************
# Root mean_square of  RandomForestRegressor() model 8.765528126321502
# cross Validation score of root mean square  RandomForestRegressor()  is  7.750293542827911
# **************************************************
# Root mean_square of  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) model 7.83273383579172
# cross Validation score of root mean square  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)  is  8.316143069527877
# **************************************************
# Root mean_square of  ElasticNet() model 7.488704640691007
# cross Validation score of root mean square  ElasticNet()  is  6.207492672775306
# **************************************************
# Root mean_square of  SGDRegressor() model 5.003950262908503
# cross Validation score of root mean square  SGDRegressor()  is  5.732055661895077
# **************************************************
# Root mean_square of  BaggingRegressor() model 8.514791052437321
# cross Validation score of root mean square  BaggingRegressor()  is  8.353422452304603
# **************************************************
# Root mean_square of  AdaBoostRegressor() model 8.05932744596783
# cross Validation score of root mean square  AdaBoostRegressor()  is  7.630246379761656
# **************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 2
#       1 for i in model:
# ----> 2     print('Root mean_square of ',i, 'model',np.sqrt(mean_squared_error(y_test,i.predict(x_test))))
#       3     score=cross_val_score(i,x,y,cv=10, scoring='neg_mean_squared_error').mean()
#       4     print("cross Validation score of root mean square ",i ," is ",np.sqrt(-score))
#
# TypeError: GradientBoostingRegressor.predict() missing 1 required positional argument: 'X'

# %% [markdown]
# # HYPERTUNNING OF XGBREGRESSOR

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={"learning_rate":[0.01,.05,.1,.2,.3,.5],
       "max_depth":[3,4,5,6,8],
       "min_cgild_weight":[1,3,5,7],
       "gamma":[0.01,0.05,0.1,0.2,0.3],
       "colsample_bytree":[0.3,0.4,0.5,0.7]}

# %%
GCV= GridSearchCV(XBG_model,params,cv=5,scoring='neg_mean_squared_error', n_jobs=-1)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.3, 0.4, 0.5, 0.7],
#                          'gamma': [0.01, 0.05, 0.1, 0.2, 0.3],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5],
#                          'max_depth': [3, 4, 5, 6, 8],
#                          'min_cgild_weight': [1, 3, 5, 7]},
#              scoring='neg_mean_squared_error')

# %%
GCV.best_params_
# Out:
# {'colsample_bytree': 0.4,
#  'gamma': 0.01,
#  'learning_rate': 0.05,
#  'max_depth': 5,
#  'min_cgild_weight': 1}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)
mean_squared_error(y_test,GCV_pred)
# Out:
# 80.97724227110545

# %% [markdown]
# Error has been reduced to 80

# %% [markdown]
# # SAVING MODEL IN PICKLE FORMAT

# %%
import joblib
joblib.dump(GCV.best_estimator_,"Baseball.pkl")
# Out:
# ['Baseball.pkl']
